# %%
import os, sys, subprocess

PINNACLE = r"C:\Users\xan37\Documents\GitHub\PINNsAgent_Codes\pinnacle"
TESTPATH = r"C:\Users\xan37\Documents\GitHub\cardiac-agent\data\fenton_karma\test"

env = {**os.environ, "DDE_BACKEND": "pytorch", "PYTHONUTF8": "1"}

def run(args):
    p = subprocess.Popen([sys.executable, *args], cwd=PINNACLE, env=env,
                         stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
                         text=True, bufsize=1)
    for line in p.stdout:
        print(line, end="")
    p.wait()
    print(f"\n[exit {p.returncode}]")
    return p.returncode

run(["scripts/gen_fenton_karma_batch.py", "--testpath", TESTPATH])
run(["scripts/eval_test_set.py", "--instances", "10-11", "--iter", "2000"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5098/3340899108.py in <cell line: 0>()
#      16     return p.returncode
#      17
# ---> 18 run(["scripts/gen_fenton_karma_batch.py", "--testpath", TESTPATH])
#      19 run(["scripts/eval_test_set.py", "--instances", "10-11", "--iter", "2000"])
#
# /tmp/ipykernel_5098/3340899108.py in run(args)
#       7
#       8 def run(args):
# ----> 9     p = subprocess.Popen([sys.executable, *args], cwd=PINNACLE, env=env,
#      10                          stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
#      11                          text=True, bufsize=1)
#
# ...
